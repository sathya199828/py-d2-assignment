# %% [markdown]
# Dictionary and its default funcion

# %% [markdown]
# fromkey is used to separete and represent the keys and value

# %%
 ky={"cat","dog","rat",}

# %%
ky1=dict.fromkeys(ky)

# %%
ky1
# Out:
# {'cat': None, 'dog': None, 'rat': None}

# %% [markdown]
# values is used to show the element in dictionary

# %%
val={"ram":4,"sam":6,"sat":10}

# %%
val.values()
# Out:
# dict_values([4, 6, 10])

# %% [markdown]
# popitem that remove and return the last item

# %%
itm={"bio":78,"phy":99,"chm":90,"mat":99}

# %%
itm.popitem()
# Out:
# ('mat', 99)

# %% [markdown]
# update

# %%
up= {"bio":78,"phy":99,"chm":90,"mat":99}

# %%
up.update("his"=99)

# %%
up
# Out:
# {'a': 10, 'b': 10, 'bio': 78, 'chm': 90, 'his': 99, 'mat': 99, 'phy': 99}

# %% [markdown]
# clear ot will clear the values and makes dictionary empty

# %%
em={'a':10,'b':20,'c':90}

# %%
em.clear()

# %%
em
# Out:
# {}
