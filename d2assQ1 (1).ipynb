# %% [markdown]
# lists and its default function
#
# appent its will add the element in the end of the list

# %%
lt=[2,4,5,6,7,9]

# %%
lt.append(10)

# %%
lt
# Out:
# [2, 4, 5, 6, 7, 9, 10]

# %% [markdown]
# exdent its will join the two list

# %%
sat=[3,5,6.7,8]

# %%
ram=[9,10]

# %%
sat.extend(ram)

# %%
sat
# Out:
# [3, 5, 6.7, 8, 9, 10]

# %% [markdown]
# insert  it will insert the value in the list

# %%
ins=["pen","book","note"]

# %%
ins.insert(0,"bag")

# %%
ins
# Out:
# ['bag', 'pen', 'book', 'note']

# %% [markdown]
# pop it will remove the element in the list

# %%
num=[1,2,3,4.5]

# %%
num1=num.pop(2)

# %%
num1
# Out:
# 3

# %%
num
# Out:
# [1, 2, 4.5]

# %% [markdown]
# clear it will clear the values and make the list empty

# %%
cls=["sat","ram","book","note"]

# %%
cls.clear()

# %%
cls
# Out:
# []
