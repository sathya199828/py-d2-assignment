# %% [markdown]
# string and its function

# %% [markdown]
# lower it used to print the words in lower case

# %%
str1="SATHYA"

# %%
str1.lower()
# Out:
# 'sathya'

# %% [markdown]
# upper it used to print lower to upper case

# %%
a="sathya"

# %%
a.upper()
# Out:
# 'SATHYA'

# %% [markdown]
# replace the string

# %%
st="cold,eye,heart,leg"

# %%
st.replace('cold','nose')
# Out:
# 'nose,eye,heart,leg'

# %% [markdown]
# center it moves the string value in middle

# %%
st="my name is sathya"

# %%
st.center(30)
# Out:
# '      my name is sathya       '

# %% [markdown]
# endwith

# %%
st="python is a programming language."

# %%
st.endswith('age.')
# Out:
# False

# %%
st
# Out:
# 'python is a programming language'

# %%
st.endswith('language.')
# Out:
# True
