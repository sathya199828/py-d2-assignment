# %% [markdown]
# tuple and explore default function

# %% [markdown]
# index its show the charater of the value

# %%
ind=(2,4,3,5,4,5)

# %%
ind.index(5)
# Out:
# 3

# %% [markdown]
# slicing

# %%
a=(1,2,3,4,5,7,5,9,77)

# %%
a[1:4]
# Out:
# (2, 3, 4)

# %% [markdown]
# count tuple

# %%
tub=(2,3,5,6,4,5,3,5,6)

# %%
tub.count(5)
# Out:
# 3

# %% [markdown]
# negative tuble

# %%
a=('s','f','d','w','u')

# %%
a[-3]
# Out:
# 'd'
