# %%
sets and default function

# %% [markdown]
# add two sets

# %%
sets={1,4,5}

# %%
sets.add(2)

# %%
sets
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# clear it will clear the value

# %%
cl={2,5,6,7}

# %%
cl.clear()

# %%
cl
# Out:
# set()

# %% [markdown]
# set union it takes and list out every elements

# %%
a={2,4,3,5,6}

# %%
b={2,4,6,5,7,8}

# %%
a.union(b)
# Out:
# {2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# set intersection it takes and list out common elements

# %%
a={2,4,3,5,6}

# %%
b={2,4,6,5,7,8}

# %%
a&b
# Out:
# {2, 4, 5, 6}

# %% [markdown]
# Isdisjoint is check the condition

# %%
a={1,2,3,4,5}

# %%
b={7,8,9,10}

# %%
a.isdisjoint(b)
# Out:
# True
